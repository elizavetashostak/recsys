# %% [markdown]
# # Ranking

# %%
# %matplotlib inline
from time import time
import numpy as np
import pandas as pd
import math
import gc

# %%
def hit_rate_one(ground_truth, recommendation, k):
    if len(list(set(ground_truth) & set(recommendation[:k]))) != 0:
        return 1
    return 0

def hit_rate(ground_truth, recommendation, k):
    return sum([hit_rate_one(ground_truth[i], recommendation[i], k) for i in range(len(recommendation))]) / len(recommendation)

def get_binary_relevance(ground_truth, recomendation):
    relevance = []
    for i in range(len(recomendation)):
        if recomendation[i] in ground_truth:
            relevance.append(1)
        else:
            relevance.append(0)
    return relevance

def precision(recommendation, k):
    return sum(recommendation[:k]) / k

def AP(ground_truth, recommendation, k):
    if k > len(recommendation):
        k = len(recommendation)
    relevance = get_binary_relevance(ground_truth, recommendation)
    if sum(relevance[:k]) == 0:
        return 0
    return sum([relevance[i] * precision(relevance, i + 1) for i in range(k)]) / sum(relevance[:k])

def MAP(ground_truth, recommendation, k):
    return sum([AP(ground_truth[i], recommendation[i], k) for i in range(len(recommendation))]) / len(recommendation)

def DCG_one(ground_truth, recommendation, k):
    if k > len(recommendation):
        k = len(recommendation)
    relevance = get_binary_relevance(ground_truth, recommendation)
    return sum([(2 ** relevance[i] - 1) / (math.log2(i + 2)) for i in range(k)])

def best_DCG_one(ground_truth, recommendation, k):
    if k > len(ground_truth):
        relevance = [1] * len(ground_truth) + [0] * (k - len(ground_truth))
    else:
        relevance = [1] * k
    return sum([(2 ** relevance[i] - 1) / (math.log2(i + 2)) for i in range(k)])

def NDCG_one(ground_truth, recommendation, k):
    return DCG_one(ground_truth, recommendation, k) / best_DCG_one(ground_truth, recommendation, k)

def NDCG(ground_truth, recommendation, k):
    return sum([NDCG_one(ground_truth[i], recommendation[i], k) for i in range(len(recommendation))]) / len(recommendation)

def print_metrics(ground_truth, recommendation, k):
    df = pd.DataFrame({'metric': ['HitRate@k', 'MAP@k', 'NDCG@k'], 
                       'value': [hit_rate(ground_truth, recommendation, k),
                                 MAP(ground_truth, recommendation, k),
                                 NDCG(ground_truth, recommendation, k)]})
    print(df)

# %% [markdown]
# ## Read data

# %%
query_train = pd.read_pickle('data/df_train.pkl')

# %%
query_train.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm product_and_rating  \
# 0        1         196       9          50         0.18           196:0.18
# 1        1       10258       8          50         0.16         10258:0.16
# 2        1       10326       1          50         0.02         10326:0.02
# 3        1       12427       9          50         0.18         12427:0.18
# 4        1       13032       2          50         0.04         13032:0.04
#
#          0  1_product  2_product  3_product  ...   56_user   57_user  \
# 0    196.0  -0.002918   0.001673  -0.008010  ... -0.000432 -0.001412
# 1  10258.0   0.007623  -0.000338  -0.002633  ... -0.000432 -0.001412
# 2  10326.0   0.004164  -0.003791  -0.003216  ... -0.000432 -0.001412
# 3  12427.0   0.000076   0.002956  -0.009676  ... -0.000432 -0.001412
# 4  13032.0   0.005587   0.005941  -0.006445  ... -0.000432 -0.001412
#
#     58_user  59_user   60_user   61_user   62_user   63_user   64_user  \
# 0 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 1 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 2 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 3 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 4 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
#
#    reordered
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
#
# [5 rows x 136 columns]

# %%
query_train.shape
# Out:
# (12084910, 136)

# %%
query_test = pd.read_pickle('data/df_train_val.pkl')

# %%
query_test.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0        1         196      10          59     0.169492
# 1        1       10258       9          59     0.152542
# 2        1       10326       1          59     0.016949
# 3        1       12427      10          59     0.169492
# 4        1       13032       3          59     0.050847
#
#           product_and_rating        0  1_product  2_product  3_product  ...  \
# 0     196:0.1694915254237288    196.0   0.001409   0.005207   0.002497  ...
# 1  10258:0.15254237288135594  10258.0   0.005821   0.007413   0.000061  ...
# 2  10326:0.01694915254237288  10326.0   0.002304   0.003594   0.000376  ...
# 3   12427:0.1694915254237288  12427.0   0.005686   0.012542  -0.002346  ...
# 4  13032:0.05084745762711865  13032.0   0.004938   0.007218   0.002687  ...
#
#     56_user   57_user   58_user   59_user   60_user   61_user   62_user  \
# 0 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 1 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 2 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 3 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 4 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
#
#     63_user   64_user  reordered
# 0  0.004254 -0.004842        1.0
# 1  0.004254 -0.004842        1.0
# 2  0.004254 -0.004842        0.0
# 3  0.004254 -0.004842        0.0
# 4  0.004254 -0.004842        1.0
#
# [5 rows x 136 columns]

# %%
query_test.shape
# Out:
# (13057263, 136)

# %%
df_test_reordered_pivot = pd.read_pickle('data/df_test_reordered_pivot.pkl')
df_test_reordered_pivot = df_test_reordered_pivot.rename({'product_id':'true_label'}, axis=1)
df_test_reordered_pivot.head()
# Out:
#    user_id                                         true_label
# 0        1  [196, 25133, 38928, 26405, 39657, 10258, 13032...
# 1        2  [22963, 7963, 16589, 32792, 41787, 22825, 1364...
# 2        3         [39190, 18599, 23650, 21903, 47766, 24810]
# 3        4                              [26576, 25623, 21573]
# 4        5  [15349, 19057, 16185, 21413, 20843, 20114, 482...

# %% [markdown]
# ## LambdaRankNN

# %%
from LambdaRankNN import LambdaRankNN # https://pypi.org/project/LambdaRankNN/

# %% [markdown]
# ### Train batch 20 000

# %%
ranker = LambdaRankNN(input_size=128, hidden_layer_sizes=(16,8,), activation=('relu', 'relu',), solver='adam')

# %% [markdown]
# ### #1

# %%
query_train_lrnn_1 = query_train[query_train['user_id'] < 20000]
query_train_lrnn_1.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm product_and_rating  \
# 0        1         196       9          50         0.18           196:0.18
# 1        1       10258       8          50         0.16         10258:0.16
# 2        1       10326       1          50         0.02         10326:0.02
# 3        1       12427       9          50         0.18         12427:0.18
# 4        1       13032       2          50         0.04         13032:0.04
#
#          0  1_product  2_product  3_product  ...   56_user   57_user  \
# 0    196.0  -0.002918   0.001673  -0.008010  ... -0.000432 -0.001412
# 1  10258.0   0.007623  -0.000338  -0.002633  ... -0.000432 -0.001412
# 2  10326.0   0.004164  -0.003791  -0.003216  ... -0.000432 -0.001412
# 3  12427.0   0.000076   0.002956  -0.009676  ... -0.000432 -0.001412
# 4  13032.0   0.005587   0.005941  -0.006445  ... -0.000432 -0.001412
#
#     58_user  59_user   60_user   61_user   62_user   63_user   64_user  \
# 0 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 1 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 2 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 3 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 4 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
#
#    reordered
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_1 = np.array(query_train_lrnn_1.iloc[:, 7:135].values)
y_train_lrnn_1 = np.array(query_train_lrnn_1.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_1 = np.array(query_train_lrnn_1.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_1, y_train_lrnn_1, qid_train_lrnn_1, epochs=5)
# Out:
# Epoch 1/5
# 274152/274152 [==============================] - 217s 787us/step - loss: 0.0137
# Epoch 2/5
# 274152/274152 [==============================] - 202s 737us/step - loss: 0.0132
# Epoch 3/5
# 274152/274152 [==============================] - 198s 724us/step - loss: 0.0131
# Epoch 4/5
# 274152/274152 [==============================] - 194s 709us/step - loss: 0.0130
# Epoch 5/5
# 274152/274152 [==============================] - 199s 728us/step - loss: 0.0129
# ndcg: 0.5439999448568997
# Wall time: 31min 49s

# %%
del query_train_lrnn_1
del X_train_lrnn_1
del y_train_lrnn_1
del qid_train_lrnn_1
gc.collect()
# Out:
# 2670

# %% [markdown]
# ### #2

# %%
query_train_lrnn_2 = query_train[(query_train['user_id'] >= 20000) & (query_train['user_id'] < 40000)]
query_train_lrnn_2.head()
# Out:
#        user_id  product_id  rating  rating_sum  rating_norm  \
# 37295    20057         196      33         426     0.077465
# 37296    20057       13176       1         426     0.002347
# 37297    20057       17122      21         426     0.049296
# 37298    20057       49235       1         426     0.002347
# 37299    20057       42265       4         426     0.009390
#
#                product_and_rating        0     1_product     2_product  \
# 37295     196:0.07746478873239436    196.0 -2.918350e-03  1.673240e-03
# 37296  13176:0.002347417840375587  13176.0  8.832300e-08 -1.644630e-07
# 37297   17122:0.04929577464788732  17122.0 -3.087090e-03  4.022630e-03
# 37298  49235:0.002347417840375587  49235.0 -2.262450e-02 -1.918720e-02
# 37299  42265:0.009389671361502348  42265.0 -4.455240e-03  1.644610e-03
#
#           3_product  ...   56_user   57_user   58_user   59_user   60_user  \
# 37295 -8.009560e-03  ... -0.003194  0.000848 -0.003545 -0.000321 -0.002445
# 37296 -3.618330e-07  ... -0.003194  0.000848 -0.003545 -0.000321 -0.002445
# 37297 -6.328750e-03  ... -0.003194  0.000848 -0.003545 -0.000321 -0.002445
# 37298  4.720850e-02  ... -0.003194  0.000848 -0.003545 -0.000321 -0.002445
# 37299  7.742480e-04  ... -0.003194  0.000848 -0.003545 -0.000321 -0.002445
#
#         61_user   62_user   63_user   64_user  reordered
# 37295  0.001645  0.004606  0.000802  0.000939        1.0
# 37296  0.001645  0.004606  0.000802  0.000939        0.0
# 37297  0.001645  0.004606  0.000802  0.000939        0.0
# 37298  0.001645  0.004606  0.000802  0.000939        0.0
# 37299  0.001645  0.004606  0.000802  0.000939        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_2 = np.array(query_train_lrnn_2.iloc[:, 7:135].values)
y_train_lrnn_2 = np.array(query_train_lrnn_2.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_2 = np.array(query_train_lrnn_2.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_2, y_train_lrnn_2, qid_train_lrnn_2, epochs=5)
# Out:
# Epoch 1/5
# 279156/279156 [==============================] - 223s 796us/step - loss: 0.0130
# Epoch 2/5
# 279156/279156 [==============================] - 229s 819us/step - loss: 0.0128
# Epoch 3/5
# 279156/279156 [==============================] - 218s 780us/step - loss: 0.0127
# Epoch 4/5
# 279156/279156 [==============================] - 223s 801us/step - loss: 0.0127
# Epoch 5/5
# 279156/279156 [==============================] - 228s 819us/step - loss: 0.0127
# ndcg: 0.5472211484461429
# Wall time: 33min 18s

# %%
del query_train_lrnn_2
del X_train_lrnn_2
del y_train_lrnn_2
del qid_train_lrnn_2
gc.collect()
# Out:
# 2660

# %% [markdown]
# ### #3

# %%
query_train_lrnn_3 = query_train[(query_train['user_id'] >= 40000) & (query_train['user_id'] < 60000)]
query_train_lrnn_3.head()
# Out:
#        user_id  product_id  rating  rating_sum  rating_norm  \
# 73654    40039         196       1          16       0.0625
# 73655    40039       21150       1          16       0.0625
# 73656    40039        1511       1          16       0.0625
# 73657    40039        4660       1          16       0.0625
# 73658    40039       39177       1          16       0.0625
#
#       product_and_rating        0  1_product  2_product  3_product  ...  \
# 73654         196:0.0625    196.0  -0.002918   0.001673  -0.008010  ...
# 73655       21150:0.0625  21150.0   0.003102  -0.003429  -0.004570  ...
# 73656        1511:0.0625   1511.0   0.005748   0.001878  -0.014344  ...
# 73657        4660:0.0625   4660.0   0.027959  -0.001276  -0.068719  ...
# 73658       39177:0.0625  39177.0   0.020762  -0.000871   0.089201  ...
#
#         56_user   57_user   58_user   59_user   60_user   61_user   62_user  \
# 73654 -0.004978  0.009756  0.014309  0.000228  0.008424 -0.020917  0.004051
# 73655 -0.004978  0.009756  0.014309  0.000228  0.008424 -0.020917  0.004051
# 73656 -0.004978  0.009756  0.014309  0.000228  0.008424 -0.020917  0.004051
# 73657 -0.004978  0.009756  0.014309  0.000228  0.008424 -0.020917  0.004051
# 73658 -0.004978  0.009756  0.014309  0.000228  0.008424 -0.020917  0.004051
#
#         63_user   64_user  reordered
# 73654  0.007186  0.012614        0.0
# 73655  0.007186  0.012614        0.0
# 73656  0.007186  0.012614        0.0
# 73657  0.007186  0.012614        0.0
# 73658  0.007186  0.012614        1.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_3 = np.array(query_train_lrnn_3.iloc[:, 7:135].values)
y_train_lrnn_3 = np.array(query_train_lrnn_3.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_3 = np.array(query_train_lrnn_3.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_3, y_train_lrnn_3, qid_train_lrnn_3, epochs=5)
# Out:
# Epoch 1/5
# 280700/280700 [==============================] - 196s 695us/step - loss: 0.0129
# Epoch 2/5
# 280700/280700 [==============================] - 195s 696us/step - loss: 0.0128
# Epoch 3/5
# 280700/280700 [==============================] - 195s 695us/step - loss: 0.0127
# Epoch 4/5
# 280700/280700 [==============================] - 196s 697us/step - loss: 0.0127
# Epoch 5/5
# 280700/280700 [==============================] - 217s 774us/step - loss: 0.0126
# ndcg: 0.5449936745373245
# Wall time: 30min 25s

# %%
del query_train_lrnn_3
del X_train_lrnn_3
del y_train_lrnn_3
del qid_train_lrnn_3
gc.collect()
# Out:
# 2660

# %%
# import pickle
# pickle.dump(ranker, open('ranker_3.pkl', 'w'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-1573cac96a97> in <module>
# ----> 1 pickle.dump(ranker, open('ranker_3.pkl', 'w'))
#
# TypeError: cannot pickle 'weakref' object

# %%
# from rankerNN2pmml import rankerNN2pmml
# params = {
#     'feature_names': list(query_train.columns)[7:135],
#     'target_name': 'reordered'
# }

# rankerNN2pmml(estimator=ranker.model, file='Model_example.xml', **params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-3a2fe71174bc> in <module>
#       5 }
#       6
# ----> 7 rankerNN2pmml(estimator=ranker.model, file='Model_example.xml', **params)
#
# ~\Anaconda3\lib\site-packages\rankerNN2pmml\__init__.py in rankerNN2pmml(estimator, transformer, file, **kwargs)
#     205     target_name = kwargs.get('target_name', 'score')
#     206     model_name = kwargs.get('model_name', None)
# --> 207     feature_names = _validate_inputs(estimator, transformer, feature_names)
#     208
#     209     pmml = ET.Element('PMML')
#
# ~\Anaconda3\lib\site-packages\rankerNN2pmml\__init__.py in _validate_inputs(model, transformer, feature_names)
#      27 def _validate_inputs(model, transformer, feature_names):
#      28     if not type(model) in SUPPORTED_MODELS:
# ---> 29         raise TypeError("Provided model is not supported.")
#      30     if not model.built:
#      31         raise TypeError("Provided model is not fitted.")
#
# TypeError: Provided model is not supported.

# %% [markdown]
# ### #4

# %%
query_train_lrnn_4 = query_train[(query_train['user_id'] >= 60000) & (query_train['user_id'] < 80000)]
query_train_lrnn_4.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 114081    60010         196       1          27     0.037037
# 114082    60010        5782       1          27     0.037037
# 114083    60010       19468       1          27     0.037037
# 114084    60010       44234       1          27     0.037037
# 114085    60010       30696       1          27     0.037037
#
#                 product_and_rating        0  1_product  2_product  3_product  \
# 114081    196:0.037037037037037035    196.0  -0.002918   0.001673  -0.008010
# 114082   5782:0.037037037037037035   5782.0   0.003811   0.000288  -0.010749
# 114083  19468:0.037037037037037035  19468.0  -0.005127  -0.001757   0.009880
# 114084  44234:0.037037037037037035  44234.0  -0.014767  -0.008047   0.022281
# 114085  30696:0.037037037037037035  30696.0   0.004183  -0.009553   0.013456
#
#         ...   56_user  57_user   58_user   59_user   60_user   61_user  \
# 114081  ... -0.002441   0.0042  0.007815 -0.004061  0.010253  0.002459
# 114082  ... -0.002441   0.0042  0.007815 -0.004061  0.010253  0.002459
# 114083  ... -0.002441   0.0042  0.007815 -0.004061  0.010253  0.002459
# 114084  ... -0.002441   0.0042  0.007815 -0.004061  0.010253  0.002459
# 114085  ... -0.002441   0.0042  0.007815 -0.004061  0.010253  0.002459
#
#          62_user   63_user   64_user  reordered
# 114081  0.001121  0.007863  0.007912        0.0
# 114082  0.001121  0.007863  0.007912        0.0
# 114083  0.001121  0.007863  0.007912        0.0
# 114084  0.001121  0.007863  0.007912        0.0
# 114085  0.001121  0.007863  0.007912        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_4 = np.array(query_train_lrnn_4.iloc[:, 7:135].values)
y_train_lrnn_4 = np.array(query_train_lrnn_4.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_4 = np.array(query_train_lrnn_4.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_4, y_train_lrnn_4, qid_train_lrnn_4, epochs=5)
# Out:
# Epoch 1/5
# 285408/285408 [==============================] - 223s 778us/step - loss: 0.0128
# Epoch 2/5
# 285408/285408 [==============================] - 219s 768us/step - loss: 0.0126
# Epoch 3/5
# 285408/285408 [==============================] - 206s 720us/step - loss: 0.0126
# Epoch 4/5
# 285408/285408 [==============================] - 213s 747us/step - loss: 0.0126
# Epoch 5/5
# 285408/285408 [==============================] - 216s 757us/step - loss: 0.0125
# ndcg: 0.5449990678247852
# Wall time: 31min 53s

# %%
del query_train_lrnn_4
del X_train_lrnn_4
del y_train_lrnn_4
del qid_train_lrnn_4
gc.collect()
# Out:
# 2660

# %% [markdown]
# ### #5

# %%
query_train_lrnn_5 = query_train[(query_train['user_id'] >= 80000) & (query_train['user_id'] < 100000)]
query_train_lrnn_5.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 150012    80002         196       2          58     0.034483
# 150013    80002       13176       1          58     0.017241
# 150014    80002       27966       1          58     0.017241
# 150015    80002       45664       1          58     0.017241
# 150016    80002       14146       2          58     0.034483
#
#                 product_and_rating        0     1_product     2_product  \
# 150012    196:0.034482758620689655    196.0 -2.918350e-03  1.673240e-03
# 150013  13176:0.017241379310344827  13176.0  8.832300e-08 -1.644630e-07
# 150014  27966:0.017241379310344827  27966.0 -1.550400e-03 -4.515680e-04
# 150015  45664:0.017241379310344827  45664.0 -2.130480e-02  1.476440e-02
# 150016  14146:0.034482758620689655  14146.0 -2.725370e-03 -1.143910e-02
#
#            3_product  ...   56_user   57_user   58_user   59_user   60_user  \
# 150012 -8.009560e-03  ...  0.000386 -0.000346  0.015087 -0.004149  0.007575
# 150013 -3.618330e-07  ...  0.000386 -0.000346  0.015087 -0.004149  0.007575
# 150014  7.160110e-03  ...  0.000386 -0.000346  0.015087 -0.004149  0.007575
# 150015  1.697660e-02  ...  0.000386 -0.000346  0.015087 -0.004149  0.007575
# 150016 -1.064440e-02  ...  0.000386 -0.000346  0.015087 -0.004149  0.007575
#
#          61_user   62_user   63_user   64_user  reordered
# 150012 -0.012935  0.003442  0.008489  0.005086        0.0
# 150013 -0.012935  0.003442  0.008489  0.005086        0.0
# 150014 -0.012935  0.003442  0.008489  0.005086        0.0
# 150015 -0.012935  0.003442  0.008489  0.005086        0.0
# 150016 -0.012935  0.003442  0.008489  0.005086        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_5 = np.array(query_train_lrnn_5.iloc[:, 7:135].values)
y_train_lrnn_5 = np.array(query_train_lrnn_5.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_5 = np.array(query_train_lrnn_5.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_5, y_train_lrnn_5, qid_train_lrnn_5, epochs=5)
# Out:
# Epoch 1/5
# 279083/279083 [==============================] - 194s 694us/step - loss: 0.0129
# Epoch 2/5
# 279083/279083 [==============================] - 194s 694us/step - loss: 0.0128
# Epoch 3/5
# 279083/279083 [==============================] - 194s 694us/step - loss: 0.0128
# Epoch 4/5
# 279083/279083 [==============================] - 194s 695us/step - loss: 0.0127
# Epoch 5/5
# 279083/279083 [==============================] - 199s 714us/step - loss: 0.0127
# ndcg: 0.5442092044362319
# Wall time: 29min 36s

# %%
del query_train_lrnn_5
del X_train_lrnn_5
del y_train_lrnn_5
del qid_train_lrnn_5
gc.collect()
# Out:
# 2660

# %% [markdown]
# ### #6

# %%
query_train_lrnn_6 = query_train[(query_train['user_id'] >= 100000) & (query_train['user_id'] < 120000)]
query_train_lrnn_6.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 188586   100002         196       1          35     0.028571
# 188587   100002       42450       2          35     0.057143
# 188588   100002       41351       1          35     0.028571
# 188589   100002       38049       3          35     0.085714
# 188590   100002       26172       9          35     0.257143
#
#                product_and_rating        0  1_product  2_product  3_product  \
# 188586    196:0.02857142857142857    196.0  -0.002918   0.001673  -0.008010
# 188587  42450:0.05714285714285714  42450.0  -0.012292   0.015248   0.004069
# 188588  41351:0.02857142857142857  41351.0  -0.020330  -0.020794   0.047650
# 188589  38049:0.08571428571428572  38049.0   0.004313  -0.010814   0.046671
# 188590   26172:0.2571428571428571  26172.0  -0.012826  -0.035080   0.014069
#
#         ...   56_user   57_user   58_user  59_user   60_user  61_user  \
# 188586  ... -0.002616  0.015334  0.010004 -0.01032  0.009768 -0.00452
# 188587  ... -0.002616  0.015334  0.010004 -0.01032  0.009768 -0.00452
# 188588  ... -0.002616  0.015334  0.010004 -0.01032  0.009768 -0.00452
# 188589  ... -0.002616  0.015334  0.010004 -0.01032  0.009768 -0.00452
# 188590  ... -0.002616  0.015334  0.010004 -0.01032  0.009768 -0.00452
#
#         62_user   63_user   64_user  reordered
# 188586 -0.00351  0.012061 -0.001351        0.0
# 188587 -0.00351  0.012061 -0.001351        1.0
# 188588 -0.00351  0.012061 -0.001351        0.0
# 188589 -0.00351  0.012061 -0.001351        1.0
# 188590 -0.00351  0.012061 -0.001351        1.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_6 = np.array(query_train_lrnn_6.iloc[:, 7:135].values)
y_train_lrnn_6 = np.array(query_train_lrnn_6.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_6 = np.array(query_train_lrnn_6.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_6, y_train_lrnn_6, qid_train_lrnn_6, epochs=5)
# Out:
# Epoch 1/5
# 279485/279485 [==============================] - 210s 749us/step - loss: 0.0128
# Epoch 2/5
# 279485/279485 [==============================] - 199s 711us/step - loss: 0.0127
# Epoch 3/5
# 279485/279485 [==============================] - 197s 706us/step - loss: 0.0127
# Epoch 4/5
# 279485/279485 [==============================] - 198s 710us/step - loss: 0.0126
# Epoch 5/5
# 279485/279485 [==============================] - 198s 709us/step - loss: 0.0126
# ndcg: 0.5423239151172106
# Wall time: 30min 27s

# %%
del query_train_lrnn_6
del X_train_lrnn_6
del y_train_lrnn_6
del qid_train_lrnn_6
gc.collect()
# Out:
# 2660

# %% [markdown]
# ### #7

# %%
query_train_lrnn_7 = query_train[(query_train['user_id'] >= 120000) & (query_train['user_id'] < 140000)]
query_train_lrnn_7.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 229051   120020         196       2          98     0.020408
# 229052   120020       49235       2          98     0.020408
# 229053   120020        1559       1          98     0.010204
# 229054   120020       21709       1          98     0.010204
# 229055   120020       24954       1          98     0.010204
#
#                product_and_rating        0  1_product  2_product  3_product  \
# 229051    196:0.02040816326530612    196.0  -0.002918   0.001673  -0.008010
# 229052  49235:0.02040816326530612  49235.0  -0.022624  -0.019187   0.047209
# 229053   1559:0.01020408163265306   1559.0   0.006028  -0.005067  -0.010621
# 229054  21709:0.01020408163265306  21709.0  -0.003349  -0.004136   0.005443
# 229055  24954:0.01020408163265306  24954.0  -0.007780  -0.002499   0.014989
#
#         ...   56_user   57_user   58_user   59_user   60_user   61_user  \
# 229051  ... -0.001647 -0.006543  0.008296  0.002089  0.004976 -0.004198
# 229052  ... -0.001647 -0.006543  0.008296  0.002089  0.004976 -0.004198
# 229053  ... -0.001647 -0.006543  0.008296  0.002089  0.004976 -0.004198
# 229054  ... -0.001647 -0.006543  0.008296  0.002089  0.004976 -0.004198
# 229055  ... -0.001647 -0.006543  0.008296  0.002089  0.004976 -0.004198
#
#          62_user   63_user   64_user  reordered
# 229051  0.008767  0.007795  0.005214        0.0
# 229052  0.008767  0.007795  0.005214        0.0
# 229053  0.008767  0.007795  0.005214        1.0
# 229054  0.008767  0.007795  0.005214        1.0
# 229055  0.008767  0.007795  0.005214        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_7 = np.array(query_train_lrnn_7.iloc[:, 7:135].values)
y_train_lrnn_7 = np.array(query_train_lrnn_7.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_7 = np.array(query_train_lrnn_7.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_7, y_train_lrnn_7, qid_train_lrnn_7, epochs=5)
# Out:
# Epoch 1/5
# 273524/273524 [==============================] - 217s 790us/step - loss: 0.0129
# Epoch 2/5
# 273524/273524 [==============================] - 207s 756us/step - loss: 0.0128
# Epoch 3/5
# 273524/273524 [==============================] - 191s 697us/step - loss: 0.0128
# Epoch 4/5
# 273524/273524 [==============================] - 188s 687us/step - loss: 0.0127
# Epoch 5/5
# 273524/273524 [==============================] - 189s 692us/step - loss: 0.0127
# ndcg: 0.5468817128324764
# Wall time: 30min 15s

# %%
del query_train_lrnn_7
del X_train_lrnn_7
del y_train_lrnn_7
del qid_train_lrnn_7
gc.collect()
# Out:
# 2660

# %% [markdown]
# ### #8

# %%
query_train_lrnn_8 = query_train[(query_train['user_id'] >= 140000) & (query_train['user_id'] < 160000)]
query_train_lrnn_8.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 266189   140024         196       2          81     0.024691
# 266190   140024       49235      20          81     0.246914
# 266191   140024       32478      11          81     0.135802
# 266192   140024        1940       4          81     0.049383
# 266193   140024       32691       9          81     0.111111
#
#                product_and_rating        0  1_product  2_product  3_product  \
# 266189   196:0.024691358024691357    196.0  -0.002918   0.001673  -0.008010
# 266190  49235:0.24691358024691357  49235.0  -0.022624  -0.019187   0.047209
# 266191  32478:0.13580246913580246  32478.0   0.002389  -0.001738   0.011383
# 266192   1940:0.04938271604938271   1940.0   0.000798  -0.001186  -0.002575
# 266193   32691:0.1111111111111111  32691.0   0.003745   0.005060   0.015559
#
#         ...   56_user   57_user   58_user   59_user  60_user   61_user  \
# 266189  ...  0.000069  0.001226  0.004509 -0.008941 -0.00118 -0.000932
# 266190  ...  0.000069  0.001226  0.004509 -0.008941 -0.00118 -0.000932
# 266191  ...  0.000069  0.001226  0.004509 -0.008941 -0.00118 -0.000932
# 266192  ...  0.000069  0.001226  0.004509 -0.008941 -0.00118 -0.000932
# 266193  ...  0.000069  0.001226  0.004509 -0.008941 -0.00118 -0.000932
#
#          62_user   63_user   64_user  reordered
# 266189  0.006444  0.003015  0.000556        0.0
# 266190  0.006444  0.003015  0.000556        0.0
# 266191  0.006444  0.003015  0.000556        1.0
# 266192  0.006444  0.003015  0.000556        0.0
# 266193  0.006444  0.003015  0.000556        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_8 = np.array(query_train_lrnn_8.iloc[:, 7:135].values)
y_train_lrnn_8 = np.array(query_train_lrnn_8.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_8 = np.array(query_train_lrnn_8.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_8, y_train_lrnn_8, qid_train_lrnn_8, epochs=5)
# Out:
# Epoch 1/5
# 278889/278889 [==============================] - 194s 692us/step - loss: 0.0129
# Epoch 2/5
# 278889/278889 [==============================] - 191s 685us/step - loss: 0.0128
# Epoch 3/5
# 278889/278889 [==============================] - 193s 692us/step - loss: 0.0127
# Epoch 4/5
# 278889/278889 [==============================] - 196s 702us/step - loss: 0.0127
# Epoch 5/5
# 278889/278889 [==============================] - 192s 688us/step - loss: 0.0126
# ndcg: 0.5417676489076133
# Wall time: 29min 49s

# %%
del query_train_lrnn_8
del X_train_lrnn_8
del y_train_lrnn_8
del qid_train_lrnn_8
gc.collect()
# Out:
# 2660

# %% [markdown]
# ### #9

# %%
query_train_lrnn_9 = query_train[(query_train['user_id'] >= 160000) & (query_train['user_id'] < 180000)]
query_train_lrnn_9.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 304542   160060         196       8         436     0.018349
# 304543   160060       16797      10         436     0.022936
# 304544   160060       24852      15         436     0.034404
# 304545   160060       47526       1         436     0.002294
# 304546   160060       14992       5         436     0.011468
#
#                  product_and_rating        0  1_product  2_product  3_product  \
# 304542      196:0.01834862385321101    196.0  -0.002918   0.001673  -0.008010
# 304543   16797:0.022935779816513763  16797.0   0.000135   0.000303  -0.000265
# 304544   24852:0.034403669724770644  24852.0  -0.002117  -0.001905   0.001426
# 304545  47526:0.0022935779816513763  47526.0   0.000451   0.020605   0.016447
# 304546   14992:0.011467889908256881  14992.0   0.005333   0.001499  -0.004830
#
#         ...  56_user   57_user   58_user   59_user   60_user   61_user  \
# 304542  ... -0.00053  0.000487  0.006548 -0.000229  0.004948 -0.006907
# 304543  ... -0.00053  0.000487  0.006548 -0.000229  0.004948 -0.006907
# 304544  ... -0.00053  0.000487  0.006548 -0.000229  0.004948 -0.006907
# 304545  ... -0.00053  0.000487  0.006548 -0.000229  0.004948 -0.006907
# 304546  ... -0.00053  0.000487  0.006548 -0.000229  0.004948 -0.006907
#
#          62_user   63_user   64_user  reordered
# 304542 -0.002909  0.007676  0.000387        1.0
# 304543 -0.002909  0.007676  0.000387        1.0
# 304544 -0.002909  0.007676  0.000387        0.0
# 304545 -0.002909  0.007676  0.000387        0.0
# 304546 -0.002909  0.007676  0.000387        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_9 = np.array(query_train_lrnn_9.iloc[:, 7:135].values)
y_train_lrnn_9 = np.array(query_train_lrnn_9.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_9 = np.array(query_train_lrnn_9.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_9, y_train_lrnn_9, qid_train_lrnn_9, epochs=5)
# Out:
# Epoch 1/5
# 278534/278534 [==============================] - 196s 702us/step - loss: 0.0128
# Epoch 2/5
# 278534/278534 [==============================] - 191s 685us/step - loss: 0.0127
# Epoch 3/5
# 278534/278534 [==============================] - 191s 685us/step - loss: 0.0126
# Epoch 4/5
# 278534/278534 [==============================] - 192s 688us/step - loss: 0.0126
# Epoch 5/5
# 278534/278534 [==============================] - 193s 693us/step - loss: 0.0125
# ndcg: 0.5491575671456033
# Wall time: 30min 34s

# %%
del query_train_lrnn_9
del X_train_lrnn_9
del y_train_lrnn_9
del qid_train_lrnn_9
gc.collect()
# Out:
# 2660

# %% [markdown]
# ### #10

# %%
query_train_lrnn_10 = query_train[(query_train['user_id'] >= 180000) & (query_train['user_id'] < 200000)]
query_train_lrnn_10.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 339055   180010         196       1          34     0.029412
# 339056   180010        9387       1          34     0.029412
# 339057   180010       47788       1          34     0.029412
# 339058   180010       29791       1          34     0.029412
# 339059   180010       16464       1          34     0.029412
#
#                 product_and_rating        0  1_product  2_product  3_product  \
# 339055    196:0.029411764705882353    196.0  -0.002918   0.001673  -0.008010
# 339056   9387:0.029411764705882353   9387.0   0.006627  -0.000578  -0.003230
# 339057  47788:0.029411764705882353  47788.0  -0.028459   0.003021   0.051305
# 339058  29791:0.029411764705882353  29791.0   0.003771  -0.030060   0.023516
# 339059  16464:0.029411764705882353  16464.0   0.009046  -0.005595  -0.032329
#
#         ...   56_user   57_user   58_user  59_user   60_user   61_user  \
# 339055  ... -0.011921  0.005411  0.011084 -0.00341  0.010523  0.001448
# 339056  ... -0.011921  0.005411  0.011084 -0.00341  0.010523  0.001448
# 339057  ... -0.011921  0.005411  0.011084 -0.00341  0.010523  0.001448
# 339058  ... -0.011921  0.005411  0.011084 -0.00341  0.010523  0.001448
# 339059  ... -0.011921  0.005411  0.011084 -0.00341  0.010523  0.001448
#
#          62_user   63_user   64_user  reordered
# 339055 -0.006525  0.011287 -0.001111        0.0
# 339056 -0.006525  0.011287 -0.001111        0.0
# 339057 -0.006525  0.011287 -0.001111        0.0
# 339058 -0.006525  0.011287 -0.001111        0.0
# 339059 -0.006525  0.011287 -0.001111        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_10 = np.array(query_train_lrnn_10.iloc[:, 7:135].values)
y_train_lrnn_10 = np.array(query_train_lrnn_10.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_10 = np.array(query_train_lrnn_10.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_10, y_train_lrnn_10, qid_train_lrnn_10, epochs=5)
# Out:
# Epoch 1/5
# 279751/279751 [==============================] - 195s 694us/step - loss: 0.0127
# Epoch 2/5
# 279751/279751 [==============================] - 193s 689us/step - loss: 0.0126
# Epoch 3/5
# 279751/279751 [==============================] - 192s 687us/step - loss: 0.0126
# Epoch 4/5
# 279751/279751 [==============================] - 192s 686us/step - loss: 0.0125
# Epoch 5/5
# 279751/279751 [==============================] - 196s 701us/step - loss: 0.0125
# ndcg: 0.547122833208431
# Wall time: 30min 4s

# %%
del query_train_lrnn_10
del X_train_lrnn_10
del y_train_lrnn_10
del qid_train_lrnn_10
gc.collect()
# Out:
# 20

# %% [markdown]
# ### #11

# %%
query_train_lrnn_11 = query_train[query_train['user_id'] >= 200000]
query_train_lrnn_11.head()
# Out:
#         user_id  product_id  rating  rating_sum  rating_norm  \
# 376107   200005         196       4         109     0.036697
# 376108   200005       13176       2         109     0.018349
# 376109   200005       41787       1         109     0.009174
# 376110   200005        9387       1         109     0.009174
# 376111   200005       39275       3         109     0.027523
#
#                 product_and_rating        0     1_product     2_product  \
# 376107     196:0.03669724770642202    196.0 -2.918350e-03  1.673240e-03
# 376108   13176:0.01834862385321101  13176.0  8.832300e-08 -1.644630e-07
# 376109  41787:0.009174311926605505  41787.0 -6.161800e-03  4.079930e-03
# 376110   9387:0.009174311926605505   9387.0  6.626700e-03 -5.778130e-04
# 376111  39275:0.027522935779816515  39275.0 -1.685950e-03  1.031090e-03
#
#            3_product  ...   56_user   57_user   58_user   59_user   60_user  \
# 376107 -8.009560e-03  ... -0.011604  0.005131  0.001757 -0.001579 -0.006589
# 376108 -3.618330e-07  ... -0.011604  0.005131  0.001757 -0.001579 -0.006589
# 376109  1.128790e-02  ... -0.011604  0.005131  0.001757 -0.001579 -0.006589
# 376110 -3.229660e-03  ... -0.011604  0.005131  0.001757 -0.001579 -0.006589
# 376111  5.150840e-03  ... -0.011604  0.005131  0.001757 -0.001579 -0.006589
#
#         61_user  62_user   63_user   64_user  reordered
# 376107   0.0002  0.00214  0.003478  0.005386        0.0
# 376108   0.0002  0.00214  0.003478  0.005386        0.0
# 376109   0.0002  0.00214  0.003478  0.005386        0.0
# 376110   0.0002  0.00214  0.003478  0.005386        0.0
# 376111   0.0002  0.00214  0.003478  0.005386        0.0
#
# [5 rows x 136 columns]

# %%
X_train_lrnn_11 = np.array(query_train_lrnn_11.iloc[:, 7:135].values)
y_train_lrnn_11 = np.array(query_train_lrnn_11.loc[:, 'reordered'].values, dtype=np.int64)
qid_train_lrnn_11 = np.array(query_train_lrnn_11.loc[:, 'user_id'].values)

# %%
# %%time
ranker.fit(X_train_lrnn_11, y_train_lrnn_11, qid_train_lrnn_11, epochs=5)
# Out:
# Epoch 1/5
# 81817/81817 [==============================] - 56s 682us/step - loss: 0.0133
# Epoch 2/5
# 81817/81817 [==============================] - 56s 679us/step - loss: 0.0131
# Epoch 3/5
# 81817/81817 [==============================] - 56s 680us/step - loss: 0.0130
# Epoch 4/5
# 81817/81817 [==============================] - 56s 683us/step - loss: 0.0129
# Epoch 5/5
# 81817/81817 [==============================] - 56s 685us/step - loss: 0.0128
# ndcg: 0.5436368936624765
# Wall time: 8min 19s

# %%
del query_train_lrnn_11
del X_train_lrnn_11
del y_train_lrnn_11
del qid_train_lrnn_11
gc.collect()

# %%
del query_train
gc.collect()
# Out:
# 279

# %% [markdown]
# ### Test

# %%
gc.collect()
# Out:
# 20

# %%
# X_test_lrnn = np.array(query_test.iloc[:, 7:135])

# %%
# y_test_lrnn_pred = ranker.predict(X_test_lrnn)
y_test_lrnn_pred = ranker.predict(np.array(query_test.iloc[:, 7:135]))
y_test_lrnn_pred
# Out:
# array([ 6.3035746,  1.7198427,  3.723648 , ...,  1.2115352, -3.202033 ,
#        -1.3889401], dtype=float32)

# %%
query_test['LambdaRankNN_weights'] = y_test_lrnn_pred
query_test.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0        1         196      10          59     0.169492
# 1        1       10258       9          59     0.152542
# 2        1       10326       1          59     0.016949
# 3        1       12427      10          59     0.169492
# 4        1       13032       3          59     0.050847
#
#           product_and_rating        0  1_product  2_product  3_product  ...  \
# 0     196:0.1694915254237288    196.0   0.001409   0.005207   0.002497  ...
# 1  10258:0.15254237288135594  10258.0   0.005821   0.007413   0.000061  ...
# 2  10326:0.01694915254237288  10326.0   0.002304   0.003594   0.000376  ...
# 3   12427:0.1694915254237288  12427.0   0.005686   0.012542  -0.002346  ...
# 4  13032:0.05084745762711865  13032.0   0.004938   0.007218   0.002687  ...
#
#     57_user   58_user   59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 1 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 2 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 3 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 4 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
#
#     64_user  reordered  LambdaRankNN_weights
# 0 -0.004842        1.0              6.303575
# 1 -0.004842        1.0              1.719843
# 2 -0.004842        0.0              3.723648
# 3 -0.004842        0.0              4.016441
# 4 -0.004842        1.0             -0.945061
#
# [5 rows x 137 columns]

# %%
query_test.to_pickle('data/query_test.pkl')

# %%
query_test = query_test.sort_values(by=['user_id', 'LambdaRankNN_weights'], ascending=False)
query_test.reset_index(drop=True, inplace=True)
query_test.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0   206209        6825       1         129     0.007752
# 1   206209        6567       1         129     0.007752
# 2   206209       26634       1         129     0.007752
# 3   206209        1979       1         129     0.007752
# 4   206209        6846      10         129     0.077519
#
#            product_and_rating        0  1_product  2_product  3_product  ...  \
# 0   6825:0.007751937984496124   6825.0  -0.015088   0.026871  -0.020900  ...
# 1   6567:0.007751937984496124   6567.0   0.004388   0.016149  -0.001198  ...
# 2  26634:0.007751937984496124  26634.0  -0.013107  -0.010004   0.010183  ...
# 3   1979:0.007751937984496124   1979.0  -0.017001   0.012701  -0.003068  ...
# 4    6846:0.07751937984496124   6846.0   0.000177   0.019345  -0.021264  ...
#
#     57_user  58_user   59_user  60_user  61_user   62_user   63_user  \
# 0 -0.002122  0.00271 -0.002614 -0.00113 -0.00546  0.004608  0.003469
# 1 -0.002122  0.00271 -0.002614 -0.00113 -0.00546  0.004608  0.003469
# 2 -0.002122  0.00271 -0.002614 -0.00113 -0.00546  0.004608  0.003469
# 3 -0.002122  0.00271 -0.002614 -0.00113 -0.00546  0.004608  0.003469
# 4 -0.002122  0.00271 -0.002614 -0.00113 -0.00546  0.004608  0.003469
#
#     64_user  reordered  LambdaRankNN_weights
# 0 -0.000821        0.0              4.969576
# 1 -0.000821        0.0              4.432597
# 2 -0.000821        0.0              2.191908
# 3 -0.000821        0.0              2.003428
# 4 -0.000821        1.0              0.861858
#
# [5 rows x 137 columns]

# %%
query_test_pivot = query_test.pivot_table(index='user_id', values=['product_id'], 
                                                            aggfunc={'product_id': lambda x: list(x)[:10]}).reset_index()
query_test_pivot = query_test_pivot.rename({'product_id':'LambdaRankNN_recommend'}, axis=1)
query_test_pivot.head()
# Out:
#    user_id                             LambdaRankNN_recommend
# 0        1  [196, 12427, 10326, 17122, 10258, 13176, 35951...
# 1        2  [13742, 1559, 5322, 4957, 21709, 35917, 5450, ...
# 2        3  [1819, 1005, 9387, 39190, 16797, 248, 15143, 3...
# 3        4  [2707, 36606, 7350, 42329, 35469, 43704, 1200,...
# 4        5  [31717, 6808, 13988, 3376, 13870, 22475, 26604...

# %%
query_test_pivot = query_test_pivot.merge(df_test_reordered_pivot, on='user_id', how='left')
query_test_pivot.head()
# Out:
#    user_id                             LambdaRankNN_recommend  \
# 0        1  [196, 12427, 10326, 17122, 10258, 13176, 35951...
# 1        2  [13742, 1559, 5322, 4957, 21709, 35917, 5450, ...
# 2        3  [1819, 1005, 9387, 39190, 16797, 248, 15143, 3...
# 3        4  [2707, 36606, 7350, 42329, 35469, 43704, 1200,...
# 4        5  [31717, 6808, 13988, 3376, 13870, 22475, 26604...
#
#                                           true_label
# 0  [196, 25133, 38928, 26405, 39657, 10258, 13032...
# 1  [22963, 7963, 16589, 32792, 41787, 22825, 1364...
# 2         [39190, 18599, 23650, 21903, 47766, 24810]
# 3                              [26576, 25623, 21573]
# 4  [15349, 19057, 16185, 21413, 20843, 20114, 482...

# %%
query_test_pivot.to_pickle('data/query_test_pivot_LambdaRankNN.pkl')

# %%
print_metrics(query_test_pivot['true_label'], query_test_pivot['LambdaRankNN_recommend'], 10)
# Out:
#       metric     value
# 0  HitRate@k  0.653410
# 1      MAP@k  0.247062
# 2     NDCG@k  0.174280

# %% [markdown]
# ### Train all (MemoryError)

# %%
query_train.iloc[:5, 7:135]
# Out:
#    1_product  2_product  3_product  4_product  5_product  6_product  \
# 0  -0.002918   0.001673  -0.008010  -0.001002  -0.000706   0.000638
# 1   0.007623  -0.000338  -0.002633  -0.011347  -0.005478   0.007257
# 2   0.004164  -0.003791  -0.003216  -0.002906  -0.005720   0.000338
# 3   0.000076   0.002956  -0.009676  -0.003613  -0.007548  -0.003277
# 4   0.005587   0.005941  -0.006445  -0.010694  -0.008510  -0.000476
#
#    7_product  8_product  9_product  10_product  ...   55_user   56_user  \
# 0   0.001654   0.003558  -0.002566    0.000831  ... -0.000857 -0.000432
# 1   0.001760   0.015209  -0.004028    0.010140  ... -0.000857 -0.000432
# 2   0.001366  -0.001528   0.002001    0.002501  ... -0.000857 -0.000432
# 3   0.000586   0.005006   0.000649    0.011093  ... -0.000857 -0.000432
# 4  -0.000557   0.005673   0.000079    0.013272  ... -0.000857 -0.000432
#
#     57_user   58_user  59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 1 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 2 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 3 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 4 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
#
#     64_user
# 0  0.001745
# 1  0.001745
# 2  0.001745
# 3  0.001745
# 4  0.001745
#
# [5 rows x 128 columns]

# %%
X_train_lrnn = query_train.iloc[:, 7:135]
y_train_lrnn = query_train.loc[:, 'reordered'].values
qid_train_lrnn = query_train.loc[:, 'user_id'].values
qid_train_lrnn
# Out:
# array([     1,      1,      1, ..., 196943, 201262,  66343], dtype=int64)

# %%
X_train_lrnn = np.array(X_train_lrnn.values)
y_train_lrnn = np.array(y_train_lrnn, dtype=np.int64)
qid_train_lrnn = np.array(qid_train_lrnn)

# %%
ranker = LambdaRankNN(input_size=X_train_lrnn.shape[1], hidden_layer_sizes=(16,8,), activation=('relu', 'relu',), solver='adam')

# %%
# %%time
ranker.fit(X_train_lrnn, y_train_lrnn, qid_train_lrnn, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Anaconda3\lib\site-packages\LambdaRankNN\__init__.py in fit(self, X, y, qid, batch_size, epochs, verbose, validation_split)
#     119             Query id that represents the grouping of samples.
#     120         """
# --> 121         X1_trans, X2_trans, y_trans, weight = self._transform_pairwise(X, y, qid)
#     122         self.model.fit([X1_trans, X2_trans], y_trans, sample_weight=weight, batch_size=batch_size, epochs=epochs,
#     123                        verbose=verbose, validation_split=validation_split)
#
# ~\Anaconda3\lib\site-packages\LambdaRankNN\__init__.py in _transform_pairwise(self, X, y, qid)
#     301                         weight.append(delta)
#     302                         Y.append(0)
# --> 303         return np.asarray(X1), np.asarray(X2), np.asarray(Y), np.asarray(weight)
#
# ~\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# MemoryError: Unable to allocate 87.6 GiB for an array with shape (91855793, 128) and data type float64

# %%
# y_train_lrnn_pred = ranker.predict(X_train_lrnn)
# y_train_lrnn_pred

# %%
# ranker.evaluate(X_train_lrnn, y_train_lrnn, qid_train_lrnn, eval_at=10)

# %% [markdown]
# ### Train 1000 users

# %%
query_train_lrnn = query_train[query_train['user_id'] < 1000]

# %%
query_train_lrnn.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm product_and_rating  \
# 0        1         196       9          50         0.18           196:0.18
# 1        1       10258       8          50         0.16         10258:0.16
# 2        1       10326       1          50         0.02         10326:0.02
# 3        1       12427       9          50         0.18         12427:0.18
# 4        1       13032       2          50         0.04         13032:0.04
#
#          0  1_product  2_product  3_product  ...   56_user   57_user  \
# 0    196.0  -0.002918   0.001673  -0.008010  ... -0.000432 -0.001412
# 1  10258.0   0.007623  -0.000338  -0.002633  ... -0.000432 -0.001412
# 2  10326.0   0.004164  -0.003791  -0.003216  ... -0.000432 -0.001412
# 3  12427.0   0.000076   0.002956  -0.009676  ... -0.000432 -0.001412
# 4  13032.0   0.005587   0.005941  -0.006445  ... -0.000432 -0.001412
#
#     58_user  59_user   60_user   61_user   62_user   63_user   64_user  \
# 0 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 1 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 2 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 3 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 4 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
#
#    reordered
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
#
# [5 rows x 136 columns]

# %%
query_train_lrnn.iloc[:5, 7:135]
# Out:
#    1_product  2_product  3_product  4_product  5_product  6_product  \
# 0  -0.002918   0.001673  -0.008010  -0.001002  -0.000706   0.000638
# 1   0.007623  -0.000338  -0.002633  -0.011347  -0.005478   0.007257
# 2   0.004164  -0.003791  -0.003216  -0.002906  -0.005720   0.000338
# 3   0.000076   0.002956  -0.009676  -0.003613  -0.007548  -0.003277
# 4   0.005587   0.005941  -0.006445  -0.010694  -0.008510  -0.000476
#
#    7_product  8_product  9_product  10_product  ...   55_user   56_user  \
# 0   0.001654   0.003558  -0.002566    0.000831  ... -0.000857 -0.000432
# 1   0.001760   0.015209  -0.004028    0.010140  ... -0.000857 -0.000432
# 2   0.001366  -0.001528   0.002001    0.002501  ... -0.000857 -0.000432
# 3   0.000586   0.005006   0.000649    0.011093  ... -0.000857 -0.000432
# 4  -0.000557   0.005673   0.000079    0.013272  ... -0.000857 -0.000432
#
#     57_user   58_user  59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 1 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 2 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 3 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 4 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
#
#     64_user
# 0  0.001745
# 1  0.001745
# 2  0.001745
# 3  0.001745
# 4  0.001745
#
# [5 rows x 128 columns]

# %%
X_train_lrnn = query_train_lrnn.iloc[:, 7:135]
y_train_lrnn = query_train_lrnn.loc[:, 'reordered'].values
qid_train_lrnn = query_train_lrnn.loc[:, 'user_id'].values
qid_train_lrnn
# Out:
# array([  1,   1,   1, ..., 619, 686, 986], dtype=int64)

# %%
X_train_lrnn = np.array(X_train_lrnn.values)
y_train_lrnn = np.array(y_train_lrnn, dtype=np.int64)
qid_train_lrnn = np.array(qid_train_lrnn)

# %%
ranker = LambdaRankNN(input_size=X_train_lrnn.shape[1], hidden_layer_sizes=(16,8,), activation=('relu', 'relu',), solver='adam')

# %%
# %%time
ranker.fit(X_train_lrnn, y_train_lrnn, qid_train_lrnn, epochs=5)
# Out:
# Epoch 1/5
# 13731/13731 [==============================] - 10s 686us/step - loss: 0.0140
# Epoch 2/5
# 13731/13731 [==============================] - 11s 792us/step - loss: 0.0126
# Epoch 3/5
# 13731/13731 [==============================] - 10s 754us/step - loss: 0.0121
# Epoch 4/5
# 13731/13731 [==============================] - 11s 771us/step - loss: 0.0115
# Epoch 5/5
# 13731/13731 [==============================] - 11s 803us/step - loss: 0.0112
# ndcg: 0.5775741327337354
# Wall time: 1min 30s

# %%
y_train_lrnn_pred = ranker.predict(X_train_lrnn)

# %%
y_train_lrnn_pred
# Out:
# array([-1.1487375, -2.3165817, -1.7565346, ..., -3.0545864, -1.5383464,
#        -5.802136 ], dtype=float32)

# %%
ranker.evaluate(X_train_lrnn, y_train_lrnn, qid_train_lrnn, eval_at=10)
# Out:
# ndcg@10: 0.4190110123130567

# %% [markdown]
# ### Test 1000 users

# %%
query_test_lrnn = query_test[query_test['user_id'] < 1000]

# %%
query_test_lrnn.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0        1         196      10          59     0.169492
# 1        1       10258       9          59     0.152542
# 2        1       10326       1          59     0.016949
# 3        1       12427      10          59     0.169492
# 4        1       13032       3          59     0.050847
#
#           product_and_rating        0  1_product  2_product  3_product  ...  \
# 0     196:0.1694915254237288    196.0   0.001409   0.005207   0.002497  ...
# 1  10258:0.15254237288135594  10258.0   0.005821   0.007413   0.000061  ...
# 2  10326:0.01694915254237288  10326.0   0.002304   0.003594   0.000376  ...
# 3   12427:0.1694915254237288  12427.0   0.005686   0.012542  -0.002346  ...
# 4  13032:0.05084745762711865  13032.0   0.004938   0.007218   0.002687  ...
#
#     56_user   57_user   58_user   59_user   60_user   61_user   62_user  \
# 0 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 1 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 2 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 3 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 4 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
#
#     63_user   64_user  reordered
# 0  0.004254 -0.004842        1.0
# 1  0.004254 -0.004842        1.0
# 2  0.004254 -0.004842        0.0
# 3  0.004254 -0.004842        0.0
# 4  0.004254 -0.004842        1.0
#
# [5 rows x 136 columns]

# %%
query_test_lrnn.iloc[:5, 7:135]
# Out:
#    1_product  2_product  3_product  4_product  5_product  6_product  \
# 0   0.001409   0.005207   0.002497   0.001743   0.000704   0.007053
# 1   0.005821   0.007413   0.000061  -0.001078   0.001821   0.002280
# 2   0.002304   0.003594   0.000376   0.000300   0.002372   0.001176
# 3   0.005686   0.012542  -0.002346   0.008426   0.005197   0.004188
# 4   0.004938   0.007218   0.002687   0.007423   0.005073   0.001644
#
#    7_product  8_product  9_product  10_product  ...   55_user   56_user  \
# 0   0.000961   0.003151  -0.004303    0.007784  ... -0.005122 -0.003182
# 1   0.002057  -0.001182  -0.010053    0.003200  ... -0.005122 -0.003182
# 2   0.000238  -0.001016  -0.001593    0.000499  ... -0.005122 -0.003182
# 3  -0.001592  -0.004076  -0.007299   -0.001690  ... -0.005122 -0.003182
# 4   0.001098  -0.004222  -0.011638   -0.003541  ... -0.005122 -0.003182
#
#     57_user   58_user   59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 1 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 2 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 3 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 4 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
#
#     64_user
# 0 -0.004842
# 1 -0.004842
# 2 -0.004842
# 3 -0.004842
# 4 -0.004842
#
# [5 rows x 128 columns]

# %%
X_test_lrnn = query_test_lrnn.iloc[:, 7:135]
y_test_lrnn = query_test_lrnn.loc[:, 'reordered'].values
qid_test_lrnn = query_test_lrnn.loc[:, 'user_id'].values
qid_test_lrnn
# Out:
# array([  1,   1,   1, ..., 663, 619, 986], dtype=int64)

# %%
X_test_lrnn = np.array(X_test_lrnn.values)
y_test_lrnn = np.array(y_test_lrnn, dtype=np.int64)
qid_test_lrnn = np.array(qid_test_lrnn)

# %%
y_test_lrnn_pred = ranker.predict(X_test_lrnn)

# %%
y_test_lrnn_pred
# Out:
# array([ 0.537487  , -1.0570554 , -0.52575386, ..., -1.8597049 ,
#        -1.8250198 ,  0.12280083], dtype=float32)

# %%
ranker.evaluate(X_test_lrnn, y_test_lrnn, qid_test_lrnn, eval_at=10)
# Out:
# ndcg@10: 0.20935587507894388

# %%
query_test_lrnn['LambdaRankNN_proba'] = y_test_lrnn_pred
query_test_lrnn.head()
# Out:
# <ipython-input-34-c36494bed679>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_test_lrnn['LambdaRankNN_proba'] = y_test_lrnn_pred
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0        1         196      10          59     0.169492
# 1        1       10258       9          59     0.152542
# 2        1       10326       1          59     0.016949
# 3        1       12427      10          59     0.169492
# 4        1       13032       3          59     0.050847
#
#           product_and_rating        0  1_product  2_product  3_product  ...  \
# 0     196:0.1694915254237288    196.0   0.001409   0.005207   0.002497  ...
# 1  10258:0.15254237288135594  10258.0   0.005821   0.007413   0.000061  ...
# 2  10326:0.01694915254237288  10326.0   0.002304   0.003594   0.000376  ...
# 3   12427:0.1694915254237288  12427.0   0.005686   0.012542  -0.002346  ...
# 4  13032:0.05084745762711865  13032.0   0.004938   0.007218   0.002687  ...
#
#     57_user   58_user   59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 1 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 2 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 3 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 4 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
#
#     64_user  reordered  LambdaRankNN_proba
# 0 -0.004842        1.0            0.537487
# 1 -0.004842        1.0           -1.057055
# 2 -0.004842        0.0           -0.525754
# 3 -0.004842        0.0           -0.748508
# 4 -0.004842        1.0           -1.618577
#
# [5 rows x 137 columns]

# %%
query_test_lrnn = query_test_lrnn.sort_values(by=['user_id', 'LambdaRankNN_proba'], ascending=False)
query_test_lrnn.reset_index(drop=True, inplace=True)
query_test_lrnn.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0      999        1476       2         988     0.002024
# 1      999        5392       1         988     0.001012
# 2      999       39921       2         988     0.002024
# 3      999       34055       1         988     0.001012
# 4      999        2164       1         988     0.001012
#
#             product_and_rating        0  1_product  2_product  3_product  ...  \
# 0   1476:0.0020242914979757085   1476.0  -0.046046   0.026688  -0.017409  ...
# 1   5392:0.0010121457489878543   5392.0  -0.032877   0.033480   0.004977  ...
# 2  39921:0.0020242914979757085  39921.0   0.037254  -0.016318   0.038172  ...
# 3  34055:0.0010121457489878543  34055.0   0.000891  -0.008681   0.015536  ...
# 4   2164:0.0010121457489878543   2164.0  -0.012827  -0.008801  -0.005632  ...
#
#     57_user   58_user   59_user   60_user   61_user   62_user   63_user  \
# 0  0.000772  0.000749 -0.001319 -0.001663  0.002852  0.005463  0.003597
# 1  0.000772  0.000749 -0.001319 -0.001663  0.002852  0.005463  0.003597
# 2  0.000772  0.000749 -0.001319 -0.001663  0.002852  0.005463  0.003597
# 3  0.000772  0.000749 -0.001319 -0.001663  0.002852  0.005463  0.003597
# 4  0.000772  0.000749 -0.001319 -0.001663  0.002852  0.005463  0.003597
#
#     64_user  reordered  LambdaRankNN_proba
# 0  0.002072        0.0            1.247136
# 1  0.002072        0.0            1.047388
# 2  0.002072        0.0            0.715500
# 3  0.002072        0.0            0.686936
# 4  0.002072        0.0            0.585415
#
# [5 rows x 137 columns]

# %%
query_test_lrnn_pivot = query_test_lrnn.pivot_table(index='user_id', values=['product_id'], 
                                                            aggfunc={'product_id': lambda x: list(x)[:10]}).reset_index()
query_test_lrnn_pivot = query_test_lrnn_pivot.rename({'product_id':'LambdaRankNN_recommend'}, axis=1)
query_test_lrnn_pivot.head()
# Out:
#    user_id                             LambdaRankNN_recommend
# 0        1  [26088, 196, 17122, 10326, 13176, 12427, 14084...
# 1        2  [9124, 27413, 16589, 24990, 13742, 5322, 5869,...
# 2        3  [39922, 15143, 38596, 14992, 1819, 1005, 23650...
# 3        4  [7160, 17769, 42329, 43704, 2707, 11865, 7350,...
# 4        5  [15349, 43693, 6808, 21616, 13988, 40706, 3376...

# %%
query_test_lrnn_pivot = query_test_lrnn_pivot.merge(df_test_reordered_pivot, on='user_id', how='left')
query_test_lrnn_pivot.head()
# Out:
#    user_id                             LambdaRankNN_recommend  \
# 0        1  [26088, 196, 17122, 10326, 13176, 12427, 14084...
# 1        2  [9124, 27413, 16589, 24990, 13742, 5322, 5869,...
# 2        3  [39922, 15143, 38596, 14992, 1819, 1005, 23650...
# 3        4  [7160, 17769, 42329, 43704, 2707, 11865, 7350,...
# 4        5  [15349, 43693, 6808, 21616, 13988, 40706, 3376...
#
#                                           true_label
# 0  [196, 25133, 38928, 26405, 39657, 10258, 13032...
# 1  [22963, 7963, 16589, 32792, 41787, 22825, 1364...
# 2         [39190, 18599, 23650, 21903, 47766, 24810]
# 3                              [26576, 25623, 21573]
# 4  [15349, 19057, 16185, 21413, 20843, 20114, 482...

# %%
print_metrics(query_test_lrnn_pivot['true_label'], query_test_lrnn_pivot['LambdaRankNN_recommend'], 10)
# Out:
#       metric     value
# 0  HitRate@k  0.632633
# 1      MAP@k  0.244464
# 2     NDCG@k  0.167357

# %% [markdown]
# ## LambdaMART

# %%
import pyltr

# %% [markdown]
# ### Train 1000 (sklearn error)

# %%
query_train_lm = query_train[query_train['user_id'] < 1000]

# %%
query_train_lm.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm product_and_rating  \
# 0        1         196       9          50         0.18           196:0.18
# 1        1       10258       8          50         0.16         10258:0.16
# 2        1       10326       1          50         0.02         10326:0.02
# 3        1       12427       9          50         0.18         12427:0.18
# 4        1       13032       2          50         0.04         13032:0.04
#
#          0  1_product  2_product  3_product  ...   56_user   57_user  \
# 0    196.0  -0.002918   0.001673  -0.008010  ... -0.000432 -0.001412
# 1  10258.0   0.007623  -0.000338  -0.002633  ... -0.000432 -0.001412
# 2  10326.0   0.004164  -0.003791  -0.003216  ... -0.000432 -0.001412
# 3  12427.0   0.000076   0.002956  -0.009676  ... -0.000432 -0.001412
# 4  13032.0   0.005587   0.005941  -0.006445  ... -0.000432 -0.001412
#
#     58_user  59_user   60_user   61_user   62_user   63_user   64_user  \
# 0 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 1 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 2 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 3 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 4 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
#
#    reordered
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
#
# [5 rows x 136 columns]

# %%
query_train_lm.iloc[:5, 7:135]
# Out:
#    1_product  2_product  3_product  4_product  5_product  6_product  \
# 0  -0.002918   0.001673  -0.008010  -0.001002  -0.000706   0.000638
# 1   0.007623  -0.000338  -0.002633  -0.011347  -0.005478   0.007257
# 2   0.004164  -0.003791  -0.003216  -0.002906  -0.005720   0.000338
# 3   0.000076   0.002956  -0.009676  -0.003613  -0.007548  -0.003277
# 4   0.005587   0.005941  -0.006445  -0.010694  -0.008510  -0.000476
#
#    7_product  8_product  9_product  10_product  ...   55_user   56_user  \
# 0   0.001654   0.003558  -0.002566    0.000831  ... -0.000857 -0.000432
# 1   0.001760   0.015209  -0.004028    0.010140  ... -0.000857 -0.000432
# 2   0.001366  -0.001528   0.002001    0.002501  ... -0.000857 -0.000432
# 3   0.000586   0.005006   0.000649    0.011093  ... -0.000857 -0.000432
# 4  -0.000557   0.005673   0.000079    0.013272  ... -0.000857 -0.000432
#
#     57_user   58_user  59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 1 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 2 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 3 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 4 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
#
#     64_user
# 0  0.001745
# 1  0.001745
# 2  0.001745
# 3  0.001745
# 4  0.001745
#
# [5 rows x 128 columns]

# %%
X_train_lm = query_train_lm.iloc[:, 7:135]
y_train_lm = query_train_lm.loc[:, 'reordered'].values
qid_train_lm = query_train_lm.loc[:, 'user_id'].values
qid_train_lm
# Out:
# array([  1,   1,   1, ..., 619, 686, 986], dtype=int64)

# %%
metric = pyltr.metrics.NDCG(k=10)
model = pyltr.models.LambdaMART(
    metric=metric,
    n_estimators=10,
    learning_rate=0.02,
    max_features=0.5,
    query_subsample=0.5,
    max_leaf_nodes=10,
    min_samples_leaf=64,
    verbose=1,
)

# %%
model.fit(X_train_lm, y_train_lm, qid_train_lm)
# Out:
#  Iter  Train score  OOB Improve    Remaining                           Monitor Output
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-85fca96deb0e> in <module>
# ----> 1 model.fit(X_train_lm, y_train_lm, qid_train_lm)
#
# ~\Anaconda3\lib\site-packages\pyltr\models\lambdamart.py in fit(self, X, y, qids, monitor)
#     198             y_pred = self.predict(X)
#     199
# --> 200         n_stages = self._fit_stages(X, y, qids, y_pred,
#     201                                     random_state, begin_at_stage, monitor)
#     202
#
# ~\Anaconda3\lib\site-packages\pyltr\models\lambdamart.py in _fit_stages(self, X, y, qids, y_pred, random_state, begin_at_stage, monitor)
#     404                         qid, y[a:b], y_pred[a:b])
#     405
# --> 406             y_pred = self._fit_stage(i, X, y, qids, y_pred, sample_weight,
#     407                                      sample_mask, query_groups_to_use,
#     408                                      random_state)
#
# ~\Anaconda3\lib\site-packages\pyltr\models\lambdamart.py in _fit_stage(self, i, X, y, qids, y_pred, sample_weight, sample_mask, query_groups, random_state)
#     336             all_deltas[a:b] = deltas
#     337
# --> 338         tree = sklearn.tree.DecisionTreeRegressor(
#     339             criterion='friedman_mse',
#     340             splitter='best',
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# TypeError: __init__() got an unexpected keyword argument 'presort'

# %%
import sklearn
sklearn.__version__
# Out:
# '0.24.1'

# %%
# !pip install -U scikit-learn==0.21.3 --force-reinstall
# Out:
# Collecting scikit-learn==0.21.3
#   Using cached scikit-learn-0.21.3.tar.gz (12.2 MB)
# Collecting numpy>=1.11.0
#   Using cached numpy-1.20.2-cp38-cp38-win_amd64.whl (13.7 MB)
# Collecting scipy>=0.17.0
#   Using cached scipy-1.6.2-cp38-cp38-win_amd64.whl (32.7 MB)
# Collecting joblib>=0.11
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (setup.py): started
#   Building wheel for scikit-learn (setup.py): finished with status 'error'
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# Installing collected packages: numpy, scipy, joblib, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.2
#     Uninstalling numpy-1.20.2:
#       Successfully uninstalled numpy-1.20.2
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Elizaveta_Masharina\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Elizaveta_Masharina\\AppData\\Local\\Temp\\pip-install-jig0ekhw\\scikit-learn\\setup.py'"'"'; __file__='"'"'C:\\Users\\Elizaveta_Masharina\\AppData\\Local\\Temp\\pip-install-jig0ekhw\\scikit-learn\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Elizaveta_Masharina\AppData\Local\Temp\pip-wheel-0nsr61cm'
#        cwd: C:\Users\Elizaveta_Masharina\AppData\Local\Temp\pip-install-jig0ekhw\scikit-learn\
#   Complete output (33 lines):
#   Partial import of sklearn during the build process.
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Elizaveta_Masharina\AppData\Local\Temp\pip-install-jig0ekhw\scikit-learn\setup.py", line 290, in <module>
#       setup_package()
#     File "C:\Users\Elizaveta_Masharina\AppData\Local\Temp\pip-install-jig0ekhw\scikit-learn\setup.py", line 286, in setup_package
#       setup(**metadata)
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\site-packages\numpy\distutils\core.py", line 135, in setup
#       config = configuration()
#     File "C:\Users\Elizaveta_Masharina\AppData\Local\Temp\pip-install-jig0ekhw\scikit-learn\setup.py", line 174, in configuration
#       config.add_subpackage('sklearn')
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\site-packages\numpy\distutils\misc_util.py", line 1019, in add_subpackage
#       config_list = self.get_subpackage(subpackage_name, subpackage_path,
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\site-packages\numpy\distutils\misc_util.py", line 985, in get_subpackage
#       config = self._get_configuration_from_setup_py(
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\site-packages\numpy\distutils\misc_util.py", line 927, in _get_configuration_from_setup_py
#       config = setup_module.configuration(*args)
#     File "sklearn\setup.py", line 76, in configuration
#       maybe_cythonize_extensions(top_path, config)
#     File "C:\Users\Elizaveta_Masharina\AppData\Local\Temp\pip-install-jig0ekhw\scikit-learn\sklearn\_build_utils\__init__.py", line 42, in maybe_cythonize_extensions
#       with_openmp = check_openmp_support()
#     File "C:\Users\Elizaveta_Masharina\AppData\Local\Temp\pip-install-jig0ekhw\scikit-learn\sklearn\_build_utils\openmp_helpers.py", line 83, in check_openmp_support
#       ccompiler.compile(['test_openmp.c'], output_dir='objects',
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\distutils\_msvccompiler.py", line 327, in compile
#       self.initialize()
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\distutils\_msvccompiler.py", line 224, in initialize
#       vc_env = _get_vc_env(plat_spec)
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\site-packages\setuptools\msvc.py", line 312, in msvc14_get_vc_env
#       return _msvc14_get_vc_env(plat_spec)
#     File "C:\Users\Elizaveta_Masharina\Anaconda3\lib\site-packages\setuptools\msvc.py", line 266, in _msvc14_get_vc_env
#       raise distutils.errors.DistutilsPlatformError(
#   distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for scikit-learn
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] \u041e\u0442\u043a\u0430\u0437\u0430\u043d\u043e \u0432 \u0434\u043e\u0441\u0442\u0443\u043f\u0435: 'C:\\Users\\Elizaveta_Masharina\\Anaconda3\\Lib\\site-packages\\~-mpy\\.libs\\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.

# %%
# y_train_lm_pred = model.predict(X_train_lm)
# y_train_lm_pred

# %% [markdown]
# ## LGBMRanker

# %%
import lightgbm as lgb

# %% [markdown]
# ### Train (MemoryError)

# %%
query_train.iloc[:5, 7:135]
# Out:
#    1_product  2_product  3_product  4_product  5_product  6_product  \
# 0  -0.002918   0.001673  -0.008010  -0.001002  -0.000706   0.000638
# 1   0.007623  -0.000338  -0.002633  -0.011347  -0.005478   0.007257
# 2   0.004164  -0.003791  -0.003216  -0.002906  -0.005720   0.000338
# 3   0.000076   0.002956  -0.009676  -0.003613  -0.007548  -0.003277
# 4   0.005587   0.005941  -0.006445  -0.010694  -0.008510  -0.000476
#
#    7_product  8_product  9_product  10_product  ...   55_user   56_user  \
# 0   0.001654   0.003558  -0.002566    0.000831  ... -0.000857 -0.000432
# 1   0.001760   0.015209  -0.004028    0.010140  ... -0.000857 -0.000432
# 2   0.001366  -0.001528   0.002001    0.002501  ... -0.000857 -0.000432
# 3   0.000586   0.005006   0.000649    0.011093  ... -0.000857 -0.000432
# 4  -0.000557   0.005673   0.000079    0.013272  ... -0.000857 -0.000432
#
#     57_user   58_user  59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 1 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 2 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 3 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 4 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
#
#     64_user
# 0  0.001745
# 1  0.001745
# 2  0.001745
# 3  0.001745
# 4  0.001745
#
# [5 rows x 128 columns]

# %%
X_lgbm = query_train.iloc[:, 7:135]
y_lgbm = query_train.loc[:, 'reordered'].values
# qid_lgbm = query_train_lgbm.loc[:, 'user_id'].values
# qid_lgbm

# %%
from sklearn.model_selection import train_test_split
X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm = train_test_split(X_lgbm, y_lgbm, test_size=0.2, random_state=1)

# %%
query_train = [X_train_lgbm.shape[0]]
query_val = [X_val_lgbm.shape[0]]

# %%
X_train_lgbm.shape, y_train_lgbm.shape
# Out:
# ((9667928, 128), (9667928,))

# %%
gbm = lgb.LGBMRanker()

# %%
gbm.fit(X_train_lgbm, y_train_lgbm, group=query_train, 
        eval_set=[(X_val_lgbm, y_val_lgbm)], eval_group = [query_val], 
        eval_at=[5, 10, 20], early_stopping_rounds = 50)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-d195ab4f136b> in <module>
# ----> 1 gbm.fit(X_train_lgbm, y_train_lgbm, group=query_train,
#       2         eval_set=[(X_val_lgbm, y_val_lgbm)], eval_group = [query_val],
#       3         eval_at=[5, 10, 20], early_stopping_rounds = 50)
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_group, eval_metric, eval_at, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     981
#     982         self._eval_at = eval_at
# --> 983         super().fit(X, y, sample_weight=sample_weight, init_score=init_score, group=group,
#     984                     eval_set=eval_set, eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     985                     eval_init_score=eval_init_score, eval_group=eval_group, eval_metric=eval_metric,
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     681             init_model = init_model.booster_
#     682
# --> 683         self._Booster = train(params, train_set,
#     684                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     685                               early_stopping_rounds=early_stopping_rounds,
#
# ~\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2227                 )
#    2228             # construct booster object
# -> 2229             train_set.construct()
#    2230             # copy the parameters from train_set
#    2231             params.update(train_set.get_params())
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in construct(self)
#    1466             else:
#    1467                 # create train
# -> 1468                 self._lazy_init(self.data, label=self.label,
#    1469                                 weight=self.weight, group=self.group,
#    1470                                 init_score=self.init_score, predictor=self._predictor,
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1268             self.__init_from_csc(data, params_str, ref_dataset)
#    1269         elif isinstance(data, np.ndarray):
# -> 1270             self.__init_from_np2d(data, params_str, ref_dataset)
#    1271         elif isinstance(data, list) and len(data) > 0 and all(isinstance(x, np.ndarray) for x in data):
#    1272             self.__init_from_list_np2d(data, params_str, ref_dataset)
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#    1305         self.handle = ctypes.c_void_p()
#    1306         if mat.dtype == np.float32 or mat.dtype == np.float64:
# -> 1307             data = np.array(mat.reshape(mat.size), dtype=mat.dtype, copy=False)
#    1308         else:  # change non-float data to float data, need to copy
#    1309             data = np.array(mat.reshape(mat.size), dtype=np.float32)
#
# MemoryError: Unable to allocate 9.22 GiB for an array with shape (9667928, 128) and data type float64

# %%
# y_train_val_lgbm_pred = gbm.predict(X_lgbm)

# %% [markdown]
# ### Train 200 users

# %%
query_train_lgbm = query_train[query_train['user_id'] < 200]
query_train_lgbm.shape
# Out:
# (10862, 136)

# %%
query_train_lgbm.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm product_and_rating  \
# 0        1         196       9          50         0.18           196:0.18
# 1        1       10258       8          50         0.16         10258:0.16
# 2        1       10326       1          50         0.02         10326:0.02
# 3        1       12427       9          50         0.18         12427:0.18
# 4        1       13032       2          50         0.04         13032:0.04
#
#          0  1_product  2_product  3_product  ...   56_user   57_user  \
# 0    196.0  -0.002918   0.001673  -0.008010  ... -0.000432 -0.001412
# 1  10258.0   0.007623  -0.000338  -0.002633  ... -0.000432 -0.001412
# 2  10326.0   0.004164  -0.003791  -0.003216  ... -0.000432 -0.001412
# 3  12427.0   0.000076   0.002956  -0.009676  ... -0.000432 -0.001412
# 4  13032.0   0.005587   0.005941  -0.006445  ... -0.000432 -0.001412
#
#     58_user  59_user   60_user   61_user   62_user   63_user   64_user  \
# 0 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 1 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 2 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 3 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
# 4 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274  0.001745
#
#    reordered
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        1.0
#
# [5 rows x 136 columns]

# %%
query_train_lgbm.iloc[:5, 7:135]
# Out:
#    1_product  2_product  3_product  4_product  5_product  6_product  \
# 0  -0.002918   0.001673  -0.008010  -0.001002  -0.000706   0.000638
# 1   0.007623  -0.000338  -0.002633  -0.011347  -0.005478   0.007257
# 2   0.004164  -0.003791  -0.003216  -0.002906  -0.005720   0.000338
# 3   0.000076   0.002956  -0.009676  -0.003613  -0.007548  -0.003277
# 4   0.005587   0.005941  -0.006445  -0.010694  -0.008510  -0.000476
#
#    7_product  8_product  9_product  10_product  ...   55_user   56_user  \
# 0   0.001654   0.003558  -0.002566    0.000831  ... -0.000857 -0.000432
# 1   0.001760   0.015209  -0.004028    0.010140  ... -0.000857 -0.000432
# 2   0.001366  -0.001528   0.002001    0.002501  ... -0.000857 -0.000432
# 3   0.000586   0.005006   0.000649    0.011093  ... -0.000857 -0.000432
# 4  -0.000557   0.005673   0.000079    0.013272  ... -0.000857 -0.000432
#
#     57_user   58_user  59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 1 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 2 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 3 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
# 4 -0.001412 -0.005363 -0.00308 -0.007207 -0.000772  0.011067  0.002274
#
#     64_user
# 0  0.001745
# 1  0.001745
# 2  0.001745
# 3  0.001745
# 4  0.001745
#
# [5 rows x 128 columns]

# %%
X_lgbm = query_train_lgbm.iloc[:, 7:135]
y_lgbm = query_train_lgbm.loc[:, 'reordered'].values
# qid_lgbm = query_train_lgbm.loc[:, 'user_id'].values
# qid_lgbm

# %%
from sklearn.model_selection import train_test_split
X_train_lgbm, X_val_lgbm, y_train_lgbm, y_val_lgbm = train_test_split(X_lgbm, y_lgbm, test_size=0.2, random_state=1)

# %%
query_train = [X_train_lgbm.shape[0]]
query_val = [X_val_lgbm.shape[0]]

# %%
X_train_lgbm.shape, y_train_lgbm.shape
# Out:
# ((8689, 128), (8689,))

# %%
import lightgbm as lgb

# %%
gbm = lgb.LGBMRanker()

# %%
gbm.fit(X_train_lgbm, y_train_lgbm, group=query_train, 
        eval_set=[(X_val_lgbm, y_val_lgbm)], eval_group = [query_val], 
        eval_at=[5, 10, 20], early_stopping_rounds = 50)
# Out:
# [1]	valid_0's ndcg@5: 0.131205	valid_0's ndcg@10: 0.0851431	valid_0's ndcg@20: 0.163505
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's ndcg@5: 0	valid_0's ndcg@10: 0	valid_0's ndcg@20: 0.107101
# [3]	valid_0's ndcg@5: 0	valid_0's ndcg@10: 0	valid_0's ndcg@20: 0.110251
# [4]	valid_0's ndcg@5: 0	valid_0's ndcg@10: 0	valid_0's ndcg@20: 0.13875
# [5]	valid_0's ndcg@5: 0	valid_0's ndcg@10: 0.0662542	valid_0's ndcg@20: 0.152024
# [6]	valid_0's ndcg@5: 0.300785	valid_0's ndcg@10: 0.195189	valid_0's ndcg@20: 0.198416
# [7]	valid_0's ndcg@5: 0.146068	valid_0's ndcg@10: 0.230474	valid_0's ndcg@20: 0.218534
# [8]	valid_0's ndcg@5: 0.213986	valid_0's ndcg@10: 0.280882	valid_0's ndcg@20: 0.253094
# [9]	valid_0's ndcg@5: 0.345191	valid_0's ndcg@10: 0.293437	valid_0's ndcg@20: 0.25699
# [10]	valid_0's ndcg@5: 0.485229	valid_0's ndcg@10: 0.456899	valid_0's ndcg@20: 0.327206
# [11]	valid_0's ndcg@5: 0.639945	valid_0's ndcg@10: 0.415281	valid_0's ndcg@20: 0.304365
# [12]	valid_0's ndcg@5: 0.699215	valid_0's ndcg@10: 0.453743	valid_0's ndcg@20: 0.332452
# [13]	valid_0's ndcg@5: 0.722727	valid_0's ndcg@10: 0.469	valid_0's ndcg@20: 0.373097
# [14]	valid_0's ndcg@5: 0.699215	valid_0's ndcg@10: 0.453743	valid_0's ndcg@20: 0.365965
# [15]	valid_0's ndcg@5: 0.684352	valid_0's ndcg@10: 0.507718	valid_0's ndcg@20: 0.364971
# [16]	valid_0's ndcg@5: 0.684352	valid_0's ndcg@10: 0.507718	valid_0's ndcg@20: 0.361102
# [17]	valid_0's ndcg@5: 0.699215	valid_0's ndcg@10: 0.517363	valid_0's ndcg@20: 0.366228
# [18]	valid_0's ndcg@5: 0.699215	valid_0's ndcg@10: 0.517363	valid_0's ndcg@20: 0.366228
# [19]	valid_0's ndcg@5: 0.722727	valid_0's ndcg@10: 0.532621	valid_0's ndcg@20: 0.376074
# [20]	valid_0's ndcg@5: 0.722727	valid_0's ndcg@10: 0.532621	valid_0's ndcg@20: 0.343736
# [21]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.437352	valid_0's ndcg@20: 0.321874
# [22]	valid_0's ndcg@5: 0.684352	valid_0's ndcg@10: 0.444097	valid_0's ndcg@20: 0.324991
# [23]	valid_0's ndcg@5: 0.699215	valid_0's ndcg@10: 0.453743	valid_0's ndcg@20: 0.328341
# [24]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.437352	valid_0's ndcg@20: 0.349341
# [25]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.432318	valid_0's ndcg@20: 0.313754
# [26]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.311216
# [27]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.311216
# [28]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.311216
# [29]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.312822
# [30]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.311216
# [31]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.310529
# [32]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.432318	valid_0's ndcg@20: 0.313754
# [33]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.432318	valid_0's ndcg@20: 0.313754
# [34]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.311976
# [35]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.437352	valid_0's ndcg@20: 0.349868
# [36]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.432318	valid_0's ndcg@20: 0.347817
# [37]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.345279
# [38]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.425208	valid_0's ndcg@20: 0.377014
# [39]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.346726
# [40]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.432318	valid_0's ndcg@20: 0.349264
# [41]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.432318	valid_0's ndcg@20: 0.348577
# [42]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.422575	valid_0's ndcg@20: 0.34251
# [43]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.428385	valid_0's ndcg@20: 0.345413
# [44]	valid_0's ndcg@5: 0.553146	valid_0's ndcg@10: 0.425208	valid_0's ndcg@20: 0.344676
# [45]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.396392	valid_0's ndcg@20: 0.359263
# [46]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.325225
# [47]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.396392	valid_0's ndcg@20: 0.327875
# [48]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.396392	valid_0's ndcg@20: 0.35979
# [49]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.396392	valid_0's ndcg@20: 0.327188
# [50]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.396392	valid_0's ndcg@20: 0.327188
# [51]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.324538
# [52]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.323913
# [53]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.324538
# [54]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.356778
# [55]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.356778
# [56]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.356778
# [57]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.357564
# [58]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.357976
# [59]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.358354
# [60]	valid_0's ndcg@5: 0.50874	valid_0's ndcg@10: 0.393758	valid_0's ndcg@20: 0.358926
# [61]	valid_0's ndcg@5: 0.383566	valid_0's ndcg@10: 0.248908	valid_0's ndcg@20: 0.305753
# [62]	valid_0's ndcg@5: 0.383566	valid_0's ndcg@10: 0.248908	valid_0's ndcg@20: 0.305066
# [63]	valid_0's ndcg@5: 0.383566	valid_0's ndcg@10: 0.248908	valid_0's ndcg@20: 0.306513
# Early stopping, best iteration is:
# [13]	valid_0's ndcg@5: 0.722727	valid_0's ndcg@10: 0.469	valid_0's ndcg@20: 0.373097
# LGBMRanker()

# %%
y_train_val_lgbm_pred = gbm.predict(X_lgbm)

# %% [markdown]
# ### Test 200 users

# %%
query_test_lgbm = query_test[query_test['user_id'] < 200]

# %%
query_test_lgbm.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0        1         196      10          59     0.169492
# 1        1       10258       9          59     0.152542
# 2        1       10326       1          59     0.016949
# 3        1       12427      10          59     0.169492
# 4        1       13032       3          59     0.050847
#
#           product_and_rating        0  1_product  2_product  3_product  ...  \
# 0     196:0.1694915254237288    196.0   0.001409   0.005207   0.002497  ...
# 1  10258:0.15254237288135594  10258.0   0.005821   0.007413   0.000061  ...
# 2  10326:0.01694915254237288  10326.0   0.002304   0.003594   0.000376  ...
# 3   12427:0.1694915254237288  12427.0   0.005686   0.012542  -0.002346  ...
# 4  13032:0.05084745762711865  13032.0   0.004938   0.007218   0.002687  ...
#
#     56_user   57_user   58_user   59_user   60_user   61_user   62_user  \
# 0 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 1 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 2 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 3 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
# 4 -0.003182 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224
#
#     63_user   64_user  reordered
# 0  0.004254 -0.004842        1.0
# 1  0.004254 -0.004842        1.0
# 2  0.004254 -0.004842        0.0
# 3  0.004254 -0.004842        0.0
# 4  0.004254 -0.004842        1.0
#
# [5 rows x 136 columns]

# %%
query_test_lgbm.iloc[:5, 7:135]
# Out:
#    1_product  2_product  3_product  4_product  5_product  6_product  \
# 0   0.001409   0.005207   0.002497   0.001743   0.000704   0.007053
# 1   0.005821   0.007413   0.000061  -0.001078   0.001821   0.002280
# 2   0.002304   0.003594   0.000376   0.000300   0.002372   0.001176
# 3   0.005686   0.012542  -0.002346   0.008426   0.005197   0.004188
# 4   0.004938   0.007218   0.002687   0.007423   0.005073   0.001644
#
#    7_product  8_product  9_product  10_product  ...   55_user   56_user  \
# 0   0.000961   0.003151  -0.004303    0.007784  ... -0.005122 -0.003182
# 1   0.002057  -0.001182  -0.010053    0.003200  ... -0.005122 -0.003182
# 2   0.000238  -0.001016  -0.001593    0.000499  ... -0.005122 -0.003182
# 3  -0.001592  -0.004076  -0.007299   -0.001690  ... -0.005122 -0.003182
# 4   0.001098  -0.004222  -0.011638   -0.003541  ... -0.005122 -0.003182
#
#     57_user   58_user   59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 1 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 2 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 3 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 4 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
#
#     64_user
# 0 -0.004842
# 1 -0.004842
# 2 -0.004842
# 3 -0.004842
# 4 -0.004842
#
# [5 rows x 128 columns]

# %%
X_test_lgbm = query_test_lgbm.iloc[:, 7:135]
y_test_lgbm = query_test_lgbm.loc[:, 'reordered'].values
# qid_test_lgbm = query_test_lgbm.loc[:, 'user_id'].values
# qid_test_lgbm

# %%
y_test_lgbm_pred = gbm.predict(X_test_lgbm)

# %%
y_test_lgbm_pred
# Out:
# array([-1.00763234, -1.19188156, -1.06481065, ..., -1.32054768,
#        -1.291208  , -0.76003953])

# %%
query_test_lgbm['LGBMRanker_proba'] = y_test_lgbm_pred
query_test_lgbm.head()
# Out:
# <ipython-input-67-b69709882679>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   query_test_lgbm['LGBMRanker_proba'] = y_test_lgbm_pred
#    user_id  product_id  rating  rating_sum  rating_norm  \
# 0        1         196      10          59     0.169492
# 1        1       10258       9          59     0.152542
# 2        1       10326       1          59     0.016949
# 3        1       12427      10          59     0.169492
# 4        1       13032       3          59     0.050847
#
#           product_and_rating        0  1_product  2_product  3_product  ...  \
# 0     196:0.1694915254237288    196.0   0.001409   0.005207   0.002497  ...
# 1  10258:0.15254237288135594  10258.0   0.005821   0.007413   0.000061  ...
# 2  10326:0.01694915254237288  10326.0   0.002304   0.003594   0.000376  ...
# 3   12427:0.1694915254237288  12427.0   0.005686   0.012542  -0.002346  ...
# 4  13032:0.05084745762711865  13032.0   0.004938   0.007218   0.002687  ...
#
#     57_user   58_user   59_user   60_user   61_user   62_user   63_user  \
# 0 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 1 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 2 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 3 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
# 4 -0.001425 -0.000811 -0.001972 -0.005607  0.000983  0.000224  0.004254
#
#     64_user  reordered  LGBMRanker_proba
# 0 -0.004842        1.0         -1.007632
# 1 -0.004842        1.0         -1.191882
# 2 -0.004842        0.0         -1.064811
# 3 -0.004842        0.0         -0.944576
# 4 -0.004842        1.0         -1.049666
#
# [5 rows x 137 columns]

# %%
query_test_lgbm = query_test_lgbm.sort_values(by=['user_id', 'LGBMRanker_proba'], ascending=False)
query_test_lgbm.reset_index(drop=True, inplace=True)
query_test_lgbm.head()
# Out:
#    user_id  product_id  rating  rating_sum  rating_norm product_and_rating  \
# 0      199       27966       2          16       0.1250        27966:0.125
# 1      199       27521       2          16       0.1250        27521:0.125
# 2      199       28435       1          16       0.0625       28435:0.0625
# 3      199       47560       2          16       0.1250        47560:0.125
# 4      199       39275       2          16       0.1250        39275:0.125
#
#          0  1_product  2_product  3_product  ...   57_user   58_user  \
# 0  27966.0   0.000645   0.000505  -0.002225  ...  0.005682 -0.002584
# 1  27521.0  -0.005818   0.003314  -0.000094  ...  0.005682 -0.002584
# 2  28435.0  -0.014981  -0.023518  -0.046914  ...  0.005682 -0.002584
# 3  47560.0   0.027152  -0.009294  -0.015020  ...  0.005682 -0.002584
# 4  39275.0   0.002421  -0.004495  -0.000127  ...  0.005682 -0.002584
#
#     59_user   60_user   61_user  62_user   63_user   64_user  reordered  \
# 0  0.004355  0.002186 -0.001008  0.01276 -0.005409 -0.008028        0.0
# 1  0.004355  0.002186 -0.001008  0.01276 -0.005409 -0.008028        1.0
# 2  0.004355  0.002186 -0.001008  0.01276 -0.005409 -0.008028        0.0
# 3  0.004355  0.002186 -0.001008  0.01276 -0.005409 -0.008028        0.0
# 4  0.004355  0.002186 -0.001008  0.01276 -0.005409 -0.008028        0.0
#
#    LGBMRanker_proba
# 0         -1.104573
# 1         -1.104573
# 2         -1.104573
# 3         -1.127164
# 4         -1.129217
#
# [5 rows x 137 columns]

# %%
query_test_lgbm_pivot = query_test_lgbm.pivot_table(index='user_id', values=['product_id'], 
                                                            aggfunc={'product_id': lambda x: list(x)[:10]}).reset_index()
query_test_lgbm_pivot = query_test_lgbm_pivot.rename({'product_id':'LGBMRanker_recommend'}, axis=1)
query_test_lgbm_pivot.head()
# Out:
#    user_id                               LGBMRanker_recommend
# 0        1  [12427, 17122, 30450, 26088, 196, 13176, 38928...
# 1        2  [5869, 21709, 13176, 1559, 4957, 5212, 5322, 5...
# 2        3  [248, 40604, 1005, 7503, 8021, 9387, 43961, 24...
# 3        4  [2707, 17769, 1200, 25146, 7350, 11865, 7160, ...
# 4        5  [3376, 8518, 18761, 24231, 13870, 13988, 31717...

# %%
query_test_lgbm_pivot = query_test_lgbm_pivot.merge(df_test_reordered_pivot, on='user_id', how='left')
query_test_lgbm_pivot.head()
# Out:
#    user_id                               LGBMRanker_recommend  \
# 0        1  [12427, 17122, 30450, 26088, 196, 13176, 38928...
# 1        2  [5869, 21709, 13176, 1559, 4957, 5212, 5322, 5...
# 2        3  [248, 40604, 1005, 7503, 8021, 9387, 43961, 24...
# 3        4  [2707, 17769, 1200, 25146, 7350, 11865, 7160, ...
# 4        5  [3376, 8518, 18761, 24231, 13870, 13988, 31717...
#
#                                           true_label
# 0  [196, 25133, 38928, 26405, 39657, 10258, 13032...
# 1  [22963, 7963, 16589, 32792, 41787, 22825, 1364...
# 2         [39190, 18599, 23650, 21903, 47766, 24810]
# 3                              [26576, 25623, 21573]
# 4  [15349, 19057, 16185, 21413, 20843, 20114, 482...

# %%
print_metrics(query_test_lgbm_pivot['true_label'], query_test_lgbm_pivot['LGBMRanker_recommend'], 10)
# Out:
#       metric     value
# 0  HitRate@k  0.653266
# 1      MAP@k  0.252049
# 2     NDCG@k  0.163699
